# %%
import ej6
import matplotlib.pyplot as plt
import numpy as np
import math
EPS = 1.0e-4

# %%
consigna_b = ej6.armar_u_consigna(n=101, r=10)

# %%
us = ej6.generar_sistema_de_difusion(alfa=1, u=consigna_b.copy(), iteraciones=1000)
us = np.transpose(us)

plt.pcolor(us)
plt.colorbar()

plt.show()

# %%
def armar_otro_u(n, r):
    res = []
    cota_menor = math.floor(n/2) - r
    cota_mayor = math.floor(n/2) + r
    for i in range(n):
      if (i == 50):
        res.append(1)
      else:
        res.append(0)
    return res

# %%
otro = armar_otro_u(101, 10)

us = ej6.generar_sistema_de_difusion(alfa=1, u=otro.copy(), iteraciones=100)

us = np.transpose(us)

plt.pcolor(us)
plt.colorbar()

plt.show()
